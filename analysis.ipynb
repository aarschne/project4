# %%
import pandas as pd
import numpy as np

# %%
#df1 = pd.read_csv("Resources/Aggregated_Metrics_By_Country_And_Subscriber_Status.csv")
#df1
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
df2 = pd.read_csv(".\Resources\Aggregated_Metrics_By_Video.csv")
df2
# Out:
#            Video                                        Video title  \
# 0          Total                                                NaN
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                   NaN             14197   39640       3902  225021
# ...

# %%
#df3 = pd.read_csv("Resources/All_Comments_Final.csv")
#df3
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID  Reply_Count  Like_Count  \
# 0      UgxFZTIzC4UPyhhX_PZ4AaABAg            0           0
# 1      Ugx3IYuAufhb932GYQx4AaABAg            0           0
# 2      UgyhwwoK24arzRt1mud4AaABAg            0           0
# ...

# %%
#df4 = pd.read_csv("Resources/Video_Performance_Over_Time.csv")
#df4
# Out:
#                Date                                        Video Title  \
# 0       19 Jan 2022  Kaggle Project From Scratch - Part 2 (Explorat...
# 1       19 Jan 2022     Welcome To My Channel | Ken Jee | Data Science
# 2       19 Jan 2022  How She Dominated the FAANG Data Science Inter...
# 3       19 Jan 2022    The 9 Books That Changed My Perspective in 2019
# 4       19 Jan 2022  Interview with the Director of AI Research @ N...
# ...             ...                                                ...
# 111852  21 Nov 2017  Predicting Crypto-Currency Price Using RNN lST...
# 111853  20 Nov 2017  Predicting Crypto-Currency Price Using RNN lST...
# 111854  19 Nov 2017  Predicting Crypto-Currency Price Using RNN lST...
# 111855  18 Nov 2017  Predicting Crypto-Currency Price Using RNN lST...
# 111856   1 Nov 2017                     ProjectDemoCSC478_UFCFightData
#
#        External Video ID  Video Length  \
# 0            KQ80oD_boBM          2191
# ...

# %%
# Drop the header line
df2 = df2.drop(labels = 0, axis = 0)

# %%
list(df2.columns)
# Out:
# ['Video',
#  'Video title',
#  'Video pub\xadlish time',
#  'Com\xadments ad\xadded',
#  'Shares',
#  'Dis\xadlikes',
#  'Likes',
#  'Sub\xadscribers lost',
#  'Sub\xadscribers gained',
#  'RPM (USD)',
#  'CPM (USD)',
#  'Av\xader\xadage per\xadcent\xadage viewed (%)',
#  'Av\xader\xadage view dur\xada\xadtion',
#  'Views',
#  'Watch time (hours)',
#  'Sub\xadscribers',
#  'Your es\xadtim\xadated rev\xaden\xadue (USD)',
#  'Im\xadpres\xadsions',
#  'Im\xadpres\xadsions click-through rate (%)']

# %%
df2 = df2.drop(['Video', 'Video title', 'Video pub\xadlish time', 'Sub\xadscribers lost', 
                        'Sub\xadscribers gained', 'Av\xader\xadage per\xadcent\xadage viewed (%)', 
                        'Av\xader\xadage view dur\xada\xadtion', 'Sub\xadscribers', 
                        'Your es\xadtim\xadated rev\xaden\xadue (USD)', 'Im\xadpres\xadsions', 
                        'Im\xadpres\xadsions click-through rate (%)'], axis=1)

# %%
df2
# Out:
#      Com­ments ad­ded  Shares  Dis­likes  Likes  RPM (USD)  CPM (USD)  \
# 1                 907    9583        942  46903      6.353     12.835
# 2                 412       4          4    130      2.668      6.259
# 3                 402     152         15    881      9.516     11.695
# 4                 375     367         22   2622      3.143      7.943
# 5                 329     118         15    590      2.973      7.425
# ..                ...     ...        ...    ...        ...        ...
# 219                 3       5          1     48      5.218     16.232
# 220                 3       0          0     44      3.374     15.596
# 221                 3       1          0     35      3.784     12.590
# 222                 2       5          0     38      2.651     12.206
# 223                 0       2          0      1      0.050        NaN
#
#        Views  Watch time (hours)
# 1    1253559          65850.7042
# 2       2291            200.2966
# ...

# %%
list(df2.columns)
# Out:
# ['Com\xadments ad\xadded',
#  'Shares',
#  'Dis\xadlikes',
#  'Likes',
#  'RPM (USD)',
#  'CPM (USD)',
#  'Views',
#  'Watch time (hours)']

# %%
#Fix the two columns with "\xad" in it before starting
df2.rename(columns = {'Com\xadments ad\xadded':'Comments added', 'Dis\xadlikes':'Dislikes'}, inplace=True)

# %%
list(df2.columns)
# Out:
# ['Comments added',
#  'Shares',
#  'Dislikes',
#  'Likes',
#  'RPM (USD)',
#  'CPM (USD)',
#  'Views',
#  'Watch time (hours)']

# %%
df2.isna().sum()
# Out:
# Comments added        0
# Shares                0
# Dislikes              0
# Likes                 0
# RPM (USD)             0
# CPM (USD)             2
# Views                 0
# Watch time (hours)    0
# dtype: int64

# %%
#Since there are only two nulls, we'll just remove those two rows.
df2 = df2.dropna(axis=0)

# %%
df2.isna().sum()
# Out:
# Comments added        0
# Shares                0
# Dislikes              0
# Likes                 0
# RPM (USD)             0
# CPM (USD)             0
# Views                 0
# Watch time (hours)    0
# dtype: int64

# %%
#We are going to use Standard Scaler from scikit to standardize our data because some of it isn't in the same scale (RPM, CPM) as the others (Views, etc).
from sklearn.preprocessing import StandardScaler
scale = StandardScaler().fit_transform(df2)
df2_scaled = pd.DataFrame(scale, columns = df2.columns)
df2_scaled
# Out:
#      Comments added     Shares   Dislikes      Likes  RPM (USD)  CPM (USD)  \
# 0          9.196851  12.797510  13.258248  12.799840   1.073662   0.418253
# 1          3.796768  -0.238564  -0.195612  -0.247518  -1.036712  -1.553811
# 2          3.687675  -0.037151  -0.037837  -0.038026   2.885090   0.076381
# 3          3.393125   0.255443   0.062565   0.447627  -0.764682  -1.048800
# 4          2.891299  -0.083421  -0.037837  -0.119200  -0.862040  -1.204142
# ..              ...        ...        ...        ...        ...        ...
# 216       -0.654210  -0.237203  -0.252984  -0.275413   0.294227   7.900762
# 217       -0.665119  -0.237203  -0.238641  -0.270392   0.423655   1.436973
# 218       -0.665119  -0.244008  -0.252984  -0.271507  -0.632390   1.246244
# 219       -0.665119  -0.242647  -0.252984  -0.274018  -0.397586   0.344780
# 220       -0.676028  -0.237203  -0.252984  -0.273181  -1.046447   0.229623
#
#          Views  Watch time (hours)
# ...

# %%
#Ok, now we've removed and fixed up my columns, we're going to visualize some of the features against each other to see if they have any potential relationship to begin with that perhaps the clustering algorithms can utilize later. We'll also utilize a heatmap to notice correlations.
import seaborn as sns
import matplotlib.pyplot as plt
corr = df2_scaled.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df2_scaled.plot(x = "Dislikes", y = "Likes", kind="scatter")
# Out:
# <Axes: xlabel='Dislikes', ylabel='Likes'>

# %%
df2_scaled.plot(x = "Views", y = "Likes", kind="scatter")
# Out:
# <Axes: xlabel='Views', ylabel='Likes'>

# %%
#There's a clear significant outlier in the data, and We're afraid it might significantly alter the data, so We're going to remove it.
df2_scaled = df2_scaled.drop(labels = 0, axis = 0)

# %%
#Now We're going to re-run the visualizations above to see the difference.
corr = df2_scaled.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df2_scaled.plot(x = "Dislikes", y = "Likes", kind="scatter")
# Out:
# <Axes: xlabel='Dislikes', ylabel='Likes'>

# %%
df2_scaled.plot(x = "Views", y = "Likes", kind="scatter")
# Out:
# <Axes: xlabel='Views', ylabel='Likes'>

# %%
#The last step of pre-processing is use PCA to reduce the dimensionality down to 2. This will allow for better visualizations later with the clustering.
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
df2_pca = pca.fit_transform(df2_scaled)
df2_pca = pd.DataFrame(df2_pca)
df2_pca
# Out:
#             0         1
# 0   -1.648897  2.532156
# 1    2.372304  2.669044
# 2   -0.924974  2.908272
# 3   -1.268707  2.095662
# 4   -1.956391  1.925308
# ..        ...       ...
# 215  5.371036 -3.369439
# 216  1.139318 -1.154832
# 217  0.258558 -1.178226
# 218 -0.177925 -0.852888
# 219 -0.714437 -0.863014
#
# [220 rows x 2 columns]

# %%
#Next we'll be using both K-means clustering and agglomerative hierarcal clustering to see if this data can be clustered into distinctive groups.
from sklearn.cluster import KMeans, AgglomerativeClustering
inertia = [] 
for k in range(1, 10):
    kmeans = KMeans(n_clusters = k).fit(df2_pca)
    inertia.append(np.sqrt(kmeans.inertia_))
# Out:
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,10), inertia, marker = "s")
plt.xlabel("$k$")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %%
#Create another KMeans model, but this time with only 3 clusters. 
kmeans = KMeans(n_clusters=3).fit(df2_pca)
# Out:
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
values = kmeans.fit_predict(df2_pca)
# Out:
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
sns.scatterplot(x = df2_pca[0], y = df2_pca[1], hue=values)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
#So with this visualization, we can see that KMeans successfully clustered the data into 3 groups, but it seems that there are two prominent groups, then one group with less members that seem to be spread out from the other group. We're curious what these videos are.
#Now with KMeans clustering out of the way, We're going to try out agglomerative clustering and see if that comes up with different clusters than KMeans did.

#Again, to start, We need to figure out how many clusters we want the algorithm to use, so this time, We're going to create a dendrogram to figure out the ideal number of clusters.
import scipy.cluster.hierarchy as shc
plt.title("Dendrogram")
plt.xlabel("Video")
dend = shc.dendrogram(shc.linkage(df2_pca, method='ward'))

# %%
#From the dendrogram, it appears that 3 clusters will also be the ideal number, as the height between clusters is the greatest between 3 and 4 clusters.
agg = AgglomerativeClustering(n_clusters=3, affinity="euclidean", linkage="ward")

# %%
agg_values = agg.fit_predict(df2_pca)
# Out:
# c:\Users\agoya\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
sns.scatterplot(x = df2_pca[0], y = df2_pca[1], hue=agg_values)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
#As it can be seen in the scatterplot, agglomerative clustering changed the clusters slightly. There are still two larger and more significant clusters taking up most of the data, with a few changed between them, but the smaller third cluster shrank some but is still generally the outlier plots on the data.
#After running through the two clustering algorithms, KMeans and agglomerative, they actually came out with similar results. They both used 3 clusters as the ideal number of clusters and found similarly grouped clusters. The agglomerative clustering had some minor differences but mostly kept the three clusters similar to KMeans, which was two big clusters and an smaller outlier group. 

#It's interesting there's different size clusters and We're curious to know what exactly went into deciding what video went into what cluster and what the characteristics of the three different clusters are. I would also be curious how and/or if the clusters would change with a larger sample and more diverse genre of videos. This is a good start though to understanding that there are notable differences and unseen patterns to YouTube videos simply based on a few metrics.
